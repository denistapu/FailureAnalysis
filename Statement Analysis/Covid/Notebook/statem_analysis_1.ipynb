# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import os
from textstat import flesch_reading_ease

# %% [markdown]
# # Modifica dati

# %%
for i in range(1,5):
    df_filt=None
    work = pd.read_csv(f"medical{i}/workers_data.csv")
    work = work.loc[work['worker_paid']==True]
    df_subs = []
    worker_ids = np.unique(work['worker_id'].values)
    for worker_id in worker_ids:
        df_sub = work.loc[work['worker_id']==worker_id]
        most_rec_try = df_sub.loc[df_sub['current_try'].idxmax()]['current_try']
        df_sub = df_sub.loc[df_sub['current_try']==most_rec_try]
        df_subs.append(df_sub)
    df_filt = pd.concat(df_subs)
    df_filt=df_filt.drop('worker_id',axis=1)
    pathlib.Path(f"../Dati_1").mkdir(parents=True, exist_ok=True) 
    df_filt.to_csv(f"../Dati_1/data_medical_{i}.csv", index=False)

# %% [markdown]
# # Medical 1

# %%
dataf = pd.read_csv("../Dati_1/data_medical_1.csv")
dataf= dataf.loc[(dataf.doc_name!='LOW') & (dataf.doc_name!='HIGH')]
index=1
dataf
# Out:
#      unit_id  tries_amount  questionnaire_amount  dimensions_amount  \
# 0    unit_50            10                     4                  1
# 1    unit_50            10                     4                  1
# 3    unit_50            10                     4                  1
# 5    unit_50            10                     4                  1
# 6    unit_50            10                     4                  1
# ..       ...           ...                   ...                ...
# 793   unit_1            10                     4                  1
# 794   unit_1            10                     4                  1
# 795   unit_1            10                     4                  1
# 796   unit_1            10                     4                  1
# 798   unit_1            10                     4                  1
#
#      document_amount  worker_paid  current_try         q_0_age_question  \
# 0                  8         True            1  What is your age range?
# 1                  8         True            1  What is your age range?
# 3                  8         True            1  What is your age range?
# 5                  8         True            1  What is your age range?
# 6                  8         True            1  What is your age range?
# ..               ...          ...          ...                      ...
# 793                8         True            1  What is your age range?
# 794                8         True            1  What is your age range?
# 795                8         True            1  What is your age range?
# 796                8         True            1  What is your age range?
# 798                8         True            1  What is your age range?
#
#     q_0_age_answer  q_0_age_value  ...    doc_date doc_originatedFrom  \
# 0            50-80            4.0  ...  2020-25-03        Viral Image
# 1            50-80            4.0  ...  2020-23-03     Facebook Posts
# 3            50-80            4.0  ...  2020-15-03     Facebook Posts
# 5            50-80            4.0  ...    5/4/2020      CNN interview
# 6            50-80            4.0  ...   12/4/2020              Tweet
# ..             ...            ...  ...         ...                ...
# 793          26-35            2.0  ...  2020-23-03      Chain Message
# 794          26-35            2.0  ...  2020-25-03        Viral Image
# 795          26-35            2.0  ...  2020-20-03     Facebook Posts
# 796          26-35            2.0  ...  2020-19-03              Tweet
# 798          26-35            2.0  ...    2/4/2020     Facebook Posts
#
#      doc_ground_truth_value doc_ground_truth_label doc_truthfulness_value  \
# 0                       0.0          pants-on-fire                    1.0
# 1                       1.0                  FALSE                    2.0
# 3                       4.0            mostly-true                    0.0
# 5                       5.0                   TRUE                    4.0
# 6                       2.0           mostly-false                    2.0
# ..                      ...                    ...                    ...
# 793                     1.0                  FALSE                    5.0
# 794                     0.0          pants-on-fire                    1.0
# 795                     4.0            mostly-true                    3.0
# 796                     3.0              half-true                    0.0
# 798                     5.0                   TRUE                    5.0
#
#      doc_truthfulness_label  \
# 0                     FALSE
# 1              mostly-false
# 3             pants-on-fire
# 5               mostly-true
# 6              mostly-false
# ..                      ...
# 793                    TRUE
# 794                   FALSE
# 795               half-true
# 796           pants-on-fire
# 798                    TRUE
#
#                         doc_truthfulness_justification  \
# 0    A meme circulating on social media implores pe...
# 1    This type of transmission occurs via respirato...
# 3    That article was republished from InfoWars, a ...
# 5    The statement is true for the time of Mardi Gr...
# 6    February 25Dr. Anthony Fauci tells public to b...
# ..                                                 ...
# 793  I Justify this statement is true it was the po...
# 794  I Justify this statement is not accurate and C...
# 795  I justify this answer is accurate and needs to...
# 796  This statement I consider it as lie because Je...
# 798  I consider this statement is completely true i...
#
#                                   doc_truthfulness_url  doc_accesses  \
# 0    https://www.factcheck.org/2020/03/meme-mislead...           1.0
# 1    https://www.cdc.gov/coronavirus/2019-ncov/comm...           1.0
# 3    https://heavy.com/news/2020/04/bill-gates-hack...           1.0
# 5          https://www.youtube.com/watch?v=ybFMn3keujg           1.0
# 6    https://truthout.org/articles/trump-shared-a-t...           1.0
# ..                                                 ...           ...
# 793  https://www.snopes.com/fact-check/lemons-coron...           1.0
# 794  https://leadstories.com/hoax-alert/2020/03/Fac...           1.0
# 795  https://www.startribune.com/truck-drivers-are-...           1.0
# 796  https://www.reddit.com/r/NorthCarolina/comment...           1.0
# 798      https://www.facebook.com/groups/RESISTLOUDER/           1.0
#
#     doc_time_elapsed
# 0             335.53
# 1             843.47
# 3             650.36
# 5             405.08
# 6             462.50
# ..               ...
# 793           191.33
# 794           273.86
# 795           214.00
# 796           299.44
# 798           122.79
#
# [600 rows x 59 columns]

# %% [markdown]
# # Medical 2

# %%
dataf = pd.read_csv("../Dati_1/data_medical_2.csv")
dataf= dataf.loc[(dataf.doc_name!='LOW') & (dataf.doc_name!='HIGH')]
index=2
dataf
# Out:
#      unit_id  tries_amount  questionnaire_amount  dimensions_amount  \
# 0    unit_83            10                     4                  1
# 1    unit_83            10                     4                  1
# 2    unit_83            10                     4                  1
# 3    unit_83            10                     4                  1
# 4    unit_83            10                     4                  1
# ..       ...           ...                   ...                ...
# 793  unit_16            10                     4                  1
# 796  unit_16            10                     4                  1
# 797  unit_16            10                     4                  1
# 798  unit_16            10                     4                  1
# 799  unit_16            10                     4                  1
#
#      document_amount  worker_paid  current_try         q_0_age_question  \
# 0                  8         True            1  What is your age range?
# 1                  8         True            1  What is your age range?
# 2                  8         True            1  What is your age range?
# 3                  8         True            1  What is your age range?
# 4                  8         True            1  What is your age range?
# ..               ...          ...          ...                      ...
# 793                8         True            1  What is your age range?
# 796                8         True            1  What is your age range?
# 797                8         True            1  What is your age range?
# 798                8         True            1  What is your age range?
# 799                8         True            1  What is your age range?
#
#     q_0_age_answer  q_0_age_value  ...    doc_date doc_originatedFrom  \
# 0            50-80            4.0  ...  2020-16-03      Facebook Post
# 1            50-80            4.0  ...   12/3/2020              Tweet
# 2            50-80            4.0  ...  2020-28-03     Facebook Posts
# 3            50-80            4.0  ...  2020-25-03      Facebook Post
# 4            50-80            4.0  ...  2020-31-03     Facebook Posts
# ..             ...            ...  ...         ...                ...
# 793          26-35            2.0  ...  2020-13-03              Tweet
# 796          26-35            2.0  ...   10/3/2020        Viral Image
# 797          26-35            2.0  ...    2/4/2020        Viral Image
# 798          26-35            2.0  ...  2020-13-03        Viral Image
# 799          26-35            2.0  ...  2020-16-03      Facebook Post
#
#      doc_ground_truth_value doc_ground_truth_label doc_truthfulness_value  \
# 0                       0.0          pants-on-fire                    3.0
# 1                       5.0                   TRUE                    3.0
# 2                       1.0                  FALSE                    4.0
# 3                       2.0           mostly-false                    4.0
# 4                       3.0              half-true                    3.0
# ..                      ...                    ...                    ...
# 793                     5.0                   TRUE                    2.0
# 796                     3.0              half-true                    3.0
# 797                     1.0                  FALSE                    2.0
# 798                     2.0           mostly-false                    3.0
# 799                     0.0          pants-on-fire                    3.0
#
#      doc_truthfulness_label  \
# 0                 half-true
# 1                 half-true
# 2               mostly-true
# 3               mostly-true
# 4                 half-true
# ..                      ...
# 793            mostly-false
# 796               half-true
# 797            mostly-false
# 798               half-true
# 799               half-true
#
#                         doc_truthfulness_justification  \
# 0    Truthfulness is getting and synonyms of the tr...
# 1    The family of a special-needs teen is good at ...
# 2    He tried to justify his behavior by saying tha...
# 3    Ludwig is the first sentence search engine tha...
# 4    As such, it must require such a clause as an o...
# ..                                                 ...
# 793  Text (content of the statement): Says longstan...
# 796  Text (content of the statement): Harvard scien...
# 797  Text (content of the statement): Says video sh...
# 798  Text (content of the statement): President Tru...
# 799  Text (content of the statement): The governmen...
#
#                                   doc_truthfulness_url  doc_accesses  \
# 0              https://www.dictionary.com/browse/truth           1.0
# 1     https://www.imdb.com/title/tt5592146/fullcredits           1.0
# 2    https://www.merriam-webster.com/dictionary/jus...           1.0
# 3                   https://ludwig.guru/s/I+agree+that           1.0
# 4    https://thegrammarexchange.infopop.cc/topic/i-...           1.0
# ..                                                 ...           ...
# 793  https://townhall.com/tipsheet/guybenson/2020/0...           1.0
# 796  https://www.ssa.gov/OP_Home/hallex/I-02/I-2-5-...           1.0
# 797  https://about.fb.com/news/2019/07/addressing-s...           1.0
# 798  https://www.opindia.com/2020/05/viral-image-in...           1.0
# 799      https://edd.ca.gov/Unemployment/UI_Online.htm           1.0
#
#     doc_time_elapsed
# 0             150.43
# 1             115.89
# 2              53.19
# 3              54.60
# 4              87.38
# ..               ...
# 793            28.00
# 796            21.87
# 797            24.53
# 798            21.39
# 799            24.65
#
# [600 rows x 59 columns]

# %% [markdown]
# # Medical 3

# %%
dataf = pd.read_csv("../Dati_1/data_medical_3.csv")
dataf= dataf.loc[(dataf.doc_name!='LOW') & (dataf.doc_name!='HIGH')]
index=3
dataf
# Out:
#      unit_id  tries_amount  questionnaire_amount  dimensions_amount  \
# 1    unit_99            10                     4                  1
# 2    unit_99            10                     4                  1
# 4    unit_99            10                     4                  1
# 5    unit_99            10                     4                  1
# 6    unit_99            10                     4                  1
# ..       ...           ...                   ...                ...
# 794  unit_63            10                     4                  1
# 795  unit_63            10                     4                  1
# 796  unit_63            10                     4                  1
# 797  unit_63            10                     4                  1
# 798  unit_63            10                     4                  1
#
#      document_amount  worker_paid  current_try         q_0_age_question  \
# 1                  8         True            1  What is your age range?
# 2                  8         True            1  What is your age range?
# 4                  8         True            1  What is your age range?
# 5                  8         True            1  What is your age range?
# 6                  8         True            1  What is your age range?
# ..               ...          ...          ...                      ...
# 794                8         True            1  What is your age range?
# 795                8         True            1  What is your age range?
# 796                8         True            1  What is your age range?
# 797                8         True            1  What is your age range?
# 798                8         True            1  What is your age range?
#
#     q_0_age_answer  q_0_age_value  ... doc_originatedFrom doc_index  \
# 1            36-50            3.0  ...        Viral Image       1.0
# 2            36-50            3.0  ...       The Guardian       2.0
# 4            36-50            3.0  ...     Facebook Posts       4.0
# 5            36-50            3.0  ...      Facebook Post       5.0
# 6            36-50            3.0  ...     Youtube Videos       6.0
# ..             ...            ...  ...                ...       ...
# 794          36-50            3.0  ...      Facebook Post       2.0
# 795          36-50            3.0  ...      CNN Town Hall       3.0
# 796          36-50            3.0  ...     Facebook Posts       4.0
# 797          36-50            3.0  ...     Facebook Posts       5.0
# 798          36-50            3.0  ...    News Conference       6.0
#
#      doc_ground_truth_value doc_ground_truth_label doc_truthfulness_value  \
# 1                       1.0                  FALSE                    1.0
# 2                       4.0            mostly-true                    4.0
# 4                       2.0           mostly-false                    1.0
# 5                       5.0                   TRUE                    5.0
# 6                       0.0          pants-on-fire                    1.0
# ..                      ...                    ...                    ...
# 794                     0.0          pants-on-fire                    2.0
# 795                     3.0              half-true                    2.0
# 796                     1.0                  FALSE                    2.0
# 797                     2.0           mostly-false                    2.0
# 798                     5.0                   TRUE                    4.0
#
#      doc_truthfulness_label  \
# 1                     FALSE
# 2               mostly-true
# 4                     FALSE
# 5                      TRUE
# 6                     FALSE
# ..                      ...
# 794            mostly-false
# 795            mostly-false
# 796            mostly-false
# 797            mostly-false
# 798             mostly-true
#
#                         doc_truthfulness_justification  \
# 1    While gargling some combination of warm water,...
# 2    âIt has been estimated that only 12% of work...
# 4    How much does a coronavirus test cost? Fact ch...
# 5    Spectrum is offering free broadband and Wi-Fi ...
# 6    FALSE: Vatican confirms Pope Francis 'tested p...
# ..                                                 ...
# 794  The Public Feed API provides a feed of user st...
# 795  Michael Bloomberg has spent more than $350 mil...
# 796  tâs true that the Facebook algorithm isnât...
# 797  But when you list your birthday in your Facebo...
# 798  he 62-year-old dad-of-three was asked about a ...
#
#                                   doc_truthfulness_url  doc_accesses  \
# 1    https://www.snopes.com/fact-check/gargling-eli...           1.0
# 2    https://khn.org/news/sanders-in-coronavirus-re...           1.0
# 4    https://www.usatoday.com/story/news/health/202...           1.0
# 5    https://www.msn.com/en-us/news/technology/spec...           1.0
# 6    https://www.rappler.com/newsbreak/fact-check/2...           1.0
# ..                                                 ...           ...
# 794  https://developers.facebook.com/docs/public_feed/           1.0
# 795  https://www.cnn.com/2020/02/13/politics/michae...           1.0
# 796     https://blog.hootsuite.com/facebook-algorithm/           1.0
# 797  https://www.lifewire.com/things-you-should-nev...           1.0
# 798  https://nypost.com/2020/04/30/andrew-cuomo-ann...           1.0
#
#     doc_time_elapsed
# 1             125.47
# 2             147.62
# 4             286.42
# 5            1020.27
# 6              46.41
# ..               ...
# 794           260.72
# 795           291.23
# 796           304.69
# 797           311.65
# 798            85.22
#
# [600 rows x 59 columns]

# %% [markdown]
# # Medical 4

# %%
dataf = pd.read_csv("../Dati_1/data_medical_4.csv")
dataf= dataf.loc[(dataf.doc_name!='LOW') & (dataf.doc_name!='HIGH')]
index=4
dataf
# Out:
#      unit_id  tries_amount  questionnaire_amount  dimensions_amount  \
# 0    unit_58            10                     4                  1
# 1    unit_58            10                     4                  1
# 3    unit_58            10                     4                  1
# 4    unit_58            10                     4                  1
# 6    unit_58            10                     4                  1
# ..       ...           ...                   ...                ...
# 771  unit_35            10                     4                  1
# 772  unit_35            10                     4                  1
# 773  unit_35            10                     4                  1
# 774  unit_35            10                     4                  1
# 775  unit_35            10                     4                  1
#
#      document_amount  worker_paid  current_try         q_0_age_question  \
# 0                  8         True            1  What is your age range?
# 1                  8         True            1  What is your age range?
# 3                  8         True            1  What is your age range?
# 4                  8         True            1  What is your age range?
# 6                  8         True            1  What is your age range?
# ..               ...          ...          ...                      ...
# 771                8         True            1  What is your age range?
# 772                8         True            1  What is your age range?
# 773                8         True            1  What is your age range?
# 774                8         True            1  What is your age range?
# 775                8         True            1  What is your age range?
#
#     q_0_age_answer  q_0_age_value  ...    doc_date         doc_originatedFrom  \
# 0            26-35            2.0  ...  2020-23-03             Facebook Posts
# 1            26-35            2.0  ...  2020-23-03      Comments On The Radio
# 3            26-35            2.0  ...  2020-15-03             Facebook Posts
# 4            26-35            2.0  ...   12/4/2020                      Tweet
# 6            26-35            2.0  ...  2020-25-03                Viral Image
# ..             ...            ...  ...         ...                        ...
# 771          36-50            3.0  ...  2020-20-03                    Article
# 772          36-50            3.0  ...   10/3/2020                   Bloggers
# 773          36-50            3.0  ...  2020-31-03                   Briefing
# 774          36-50            3.0  ...  2020-28-03             Facebook Posts
# 775          36-50            3.0  ...    5/4/2020  ABC "This Week" interview
#
#      doc_ground_truth_value doc_ground_truth_label doc_truthfulness_value  \
# 0                       1.0                  FALSE                    2.0
# 1                       3.0              half-true                    3.0
# 3                       4.0            mostly-true                    1.0
# 4                       2.0           mostly-false                    3.0
# 6                       0.0          pants-on-fire                    3.0
# ..                      ...                    ...                    ...
# 771                     1.0                  FALSE                    5.0
# 772                     5.0                   TRUE                    3.0
# 773                     4.0            mostly-true                    1.0
# 774                     2.0           mostly-false                    5.0
# 775                     3.0              half-true                    3.0
#
#      doc_truthfulness_label  \
# 0              mostly-false
# 1                 half-true
# 3                     FALSE
# 4                 half-true
# 6                 half-true
# ..                      ...
# 771                    TRUE
# 772               half-true
# 773                   FALSE
# 774                    TRUE
# 775               half-true
#
#                         doc_truthfulness_justification  \
# 0    adding a blank line to the end of the articleâ...
# 1    happen when you copy paste text from internet ...
# 3    Use the search engine below to retrieve some e...
# 4    Use the search engine below to retrieve some e...
# 6    Use the search engine below to retrieve some e...
# ..                                                 ...
# 771  Honesty Synonyms, Honesty Antonyms | Thesaurus...
# 772  sincerity - Dictionary Definition : Vocabulary...
# 773  sincerity - Dictionary Definition : Vocabulary...
# 774  Trust - definition of trust by The Free Dictio...
# 775  Honesty - Wikipediahttps://en.wikipedia.org/wi...
#
#                                   doc_truthfulness_url  doc_accesses  \
# 0    https://work.chron.com/write-justification-rep...           1.0
# 1    https://algorithms.tutorialhorizon.com/text-ju...           1.0
# 3    https://edu.gcfglobal.org/en/internetbasics/us...           1.0
# 4    https://deepai.org/publication/can-the-crowd-i...           1.0
# 6    https://quizlet.com/290050399/business-communi...           1.0
# ..                                                 ...           ...
# 771          https://www.dictionary.com/browse/honesty           1.0
# 772        https://www.thefreedictionary.com/sincerity           1.0
# 773                https://en.wikipedia.org/wiki/Truth           1.0
# 774  https://www.fidelity.com/life-events/estate-pl...           1.0
# 775  https://www.merriam-webster.com/dictionary/hon...           1.0
#
#     doc_time_elapsed
# 0             326.09
# 1            1133.66
# 3              33.07
# 4              22.02
# 6              28.19
# ..               ...
# 771            37.00
# 772            27.07
# 773            21.45
# 774            29.41
# 775            28.29
#
# [582 rows x 59 columns]

# %% [markdown]
# # Elimina colonne che non servono all'analisi

# %%
print([col for col in dataf])

# %%
def shorten_school(x):
    if x.startswith('F'):
        return '4 year college/bachelor degree'
    elif x.startswith('H'):
        return 'High school graduate or GED (etc.)'
    elif x.startswith('P'):
        return 'Postgrad. or professional degree (etc.)'
    elif x.startswith('Some c'):
        return 'Some college (etc.)'
    elif x.startswith('Some p'):
        return 'Postgrad. or professional schooling, no degree'

# %%
data=dataf[[col for col in dataf if 
            col=='unit_id' or
            col=='current_try' or
            (col.startswith('q_0') and col.endswith('answer')) or
            (col.startswith(('q_1','q_2','q_3')) and col.endswith(('question','value'))) or
            col.endswith('elapsed') or
            (col.startswith('doc_') and (col.endswith(('doc_ground_truth_label','accesses','doc_truthfulness_url')) or not col.endswith(('label','justification','url')))) #or
            # col=='query_amount' or
            # col=='response_position' or
            # col=='selected_amount' or
            # col.startswith('sim')
             ]]
# data=data.loc[data['doc_name']!='DEM_BARELYTRUE_doc7']

data['q_1_farmers_value']=data['q_1_farmers_value'].map(lambda x: 'correct value' if x==3 else 'wrong value')
data['q_2_marks_value']=data['q_2_marks_value'].map(lambda x: 'correct value' if x==9 else 'wrong value')
data['q_3_athletics_value']=data['q_3_athletics_value'].map(lambda x: 'correct value' if x==4 else 'wrong value')
    
data['q_0_school_answer']=data['q_0_school_answer'].map(shorten_school)
data
# Out:
# <ipython-input-85-591953c9e9bb>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['q_1_farmers_value']=data['q_1_farmers_value'].map(lambda x: 'correct value' if x==3 else 'wrong value')
# <ipython-input-85-591953c9e9bb>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['q_2_marks_value']=data['q_2_marks_value'].map(lambda x: 'correct value' if x==9 else 'wrong value')
# <ipython-input-85-591953c9e9bb>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['q_3_athletics_value']=data['q_3_athletics_value'].map(lambda x: 'correct value' if x==4 else 'wrong value')
# <ipython-input-85-591953c9e9bb>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['q_0_school_answer']=data['q_0_school_answer'].map(shorten_school)
#      unit_id  current_try q_0_age_answer               q_0_school_answer  \
# 0    unit_58            1          26-35  4 year college/bachelor degree
# 1    unit_58            1          26-35  4 year college/bachelor degree
# 3    unit_58            1          26-35  4 year college/bachelor degree
# 4    unit_58            1          26-35  4 year college/bachelor degree
# 6    unit_58            1          26-35  4 year college/bachelor degree
# ..       ...          ...            ...                             ...
# 771  unit_35            1          36-50  4 year college/bachelor degree
# 772  unit_35            1          36-50  4 year college/bachelor degree
# 773  unit_35            1          36-50  4 year college/bachelor degree
# 774  unit_35            1          36-50  4 year college/bachelor degree
# 775  unit_35            1          36-50  4 year college/bachelor degree
#
#                q_0_taxes_answer q_0_political_views_answer  \
# 0    40,000 to less than 50,000                   Moderate
# 1    40,000 to less than 50,000                   Moderate
# 3    40,000 to less than 50,000                   Moderate
# 4    40,000 to less than 50,000                   Moderate
# 6    40,000 to less than 50,000                   Moderate
# ..                          ...                        ...
# 771            Less than 10,000                   Moderate
# 772            Less than 10,000                   Moderate
# 773            Less than 10,000                   Moderate
# 774            Less than 10,000                   Moderate
# 775            Less than 10,000                   Moderate
#
#     q_0_consideration_answer q_0_southern_border_answer  \
# 0                 Republican                      Agree
# 1                 Republican                      Agree
# 3                 Republican                      Agree
# 4                 Republican                      Agree
# 6                 Republican                      Agree
# ..                       ...                        ...
# 771               Republican                      Agree
# 772               Republican                      Agree
# 773               Republican                      Agree
# 774               Republican                      Agree
# 775               Republican                      Agree
#
#     q_0_environment_answer  q_0_time_elapsed  ...  \
# 0                    Agree             40.07  ...
# 1                    Agree             40.07  ...
# 3                    Agree             40.07  ...
# 4                    Agree             40.07  ...
# 6                    Agree             40.07  ...
# ..                     ...               ...  ...
# 771                  Agree             19.15  ...
# 772                  Agree             19.15  ...
# 773                  Agree             19.15  ...
# 774                  Agree             19.15  ...
# 775                  Agree             19.15  ...
#
#                                          doc_statement       doc_claimant  \
# 0    Says the CDC now says that the coronavirus can...      Facebook Post
# 1    Weâve got to give the American public a rough ...  Brian Fitzpatrick
# 3     Bill Gates told us about the coronavirus in 2015      Facebook Post
# 4    Says of COVID19 that Dr Anthony Fauci was tell...    Deanna Lorraine
# 6    If your child gets this virus their going to h...      Facebook Post
# ..                                                 ...                ...
# 771     Says COVID19 came to the United States in 2019           Bloggers
# 772                Whole of Italy goes into quarantine          Blog Post
# 773  Says for the coronavirusthe death rate in Texa...        Dan Patrick
# 774  Says for otherwise healthy peopleexperiencing ...      Facebook Post
# 775  45 nations had already movedâ to enforce trave...          Joe Biden
#
#        doc_date         doc_originatedFrom doc_ground_truth_value  \
# 0    2020-23-03             Facebook Posts                    1.0
# 1    2020-23-03      Comments On The Radio                    3.0
# 3    2020-15-03             Facebook Posts                    4.0
# 4     12/4/2020                      Tweet                    2.0
# 6    2020-25-03                Viral Image                    0.0
# ..          ...                        ...                    ...
# 771  2020-20-03                    Article                    1.0
# 772   10/3/2020                   Bloggers                    5.0
# 773  2020-31-03                   Briefing                    4.0
# 774  2020-28-03             Facebook Posts                    2.0
# 775    5/4/2020  ABC "This Week" interview                    3.0
#
#      doc_ground_truth_label doc_truthfulness_value  \
# 0                     FALSE                    2.0
# 1                 half-true                    3.0
# 3               mostly-true                    1.0
# 4              mostly-false                    3.0
# 6             pants-on-fire                    3.0
# ..                      ...                    ...
# 771                   FALSE                    5.0
# 772                    TRUE                    3.0
# 773             mostly-true                    1.0
# 774            mostly-false                    5.0
# 775               half-true                    3.0
#
#                                   doc_truthfulness_url  doc_accesses  \
# 0    https://work.chron.com/write-justification-rep...           1.0
# 1    https://algorithms.tutorialhorizon.com/text-ju...           1.0
# 3    https://edu.gcfglobal.org/en/internetbasics/us...           1.0
# 4    https://deepai.org/publication/can-the-crowd-i...           1.0
# 6    https://quizlet.com/290050399/business-communi...           1.0
# ..                                                 ...           ...
# 771          https://www.dictionary.com/browse/honesty           1.0
# 772        https://www.thefreedictionary.com/sincerity           1.0
# 773                https://en.wikipedia.org/wiki/Truth           1.0
# 774  https://www.fidelity.com/life-events/estate-pl...           1.0
# 775  https://www.merriam-webster.com/dictionary/hon...           1.0
#
#      doc_time_elapsed
# 0              326.09
# 1             1133.66
# 3               33.07
# 4               22.02
# 6               28.19
# ..                ...
# 771             37.00
# 772             27.07
# 773             21.45
# 774             29.41
# 775             28.29
#
# [582 rows x 31 columns]

# %% [markdown]
# # Creazione file rows

# %%
#numero di statement da selezionare per file delle analisi
n_stat=10

# %%
columns=['current_try' ,'q_0_age_answer', 'q_0_school_answer', 'q_0_taxes_answer',
 'q_0_political_views_answer' ,'q_0_consideration_answer',
 'q_0_southern_border_answer', 'q_0_environment_answer', 'q_1_farmers_value',
 'q_2_marks_value' ,'q_3_athletics_value' ,'doc_index', 'doc_name',
 'doc_claimant' ,'doc_truthfulness_value',
  'doc_accesses','doc_truthfulness_url']

columns_other=['doc_time_elapsed']#,'query_amount','response_position','selected_amount','sim_statem_query','sim_statem_resname','sim_statem_ressnip']

# %%
def create_rows_file(data, wrong_correct, false_true, false_true_labels, mean_col, n_stat, col_list):
#false_true_labels: lista con 1 elemento se source != 'all', altrimenti 2 elementi ['label_abc', 'label_politifact']

    data_rows=data.loc[data[f"doc_ground_truth_label"]==false_true_labels[0]]
    
    # r=data_rows.copy()
    # length=len(r)
    
    # df=pd.DataFrame(columns=['type','value','rate'])
    # for col in col_list:
    #     if(col=='doc_overall-truthfulness_url'):
    #         r['doc_overall-truthfulness_url']=r['doc_overall-truthfulness_url'].map(lambda x: x.split("/")[2])
    #     if(col=='doc_name'):
    #         r['doc_name']=r['doc_name'].map(lambda x: x.split('_')[0])
            
    #     d=r.groupby(col,as_index = False).size().rename(columns={'size':'rate', col:'value'})
    #     d['rate']/=length
    
    #     d.insert(loc=0, column='type', value=col)
    #     df=pd.concat([df, d])
            
    # pathlib.Path(f"../Dati_1/ratio_data").mkdir(parents=True, exist_ok=True) 
    # df.to_csv(f"../Dati_1/ratio_data/ratio_{false_true}_{source}_{n_stat}.csv", index=False)
    
    statements_rows=data_rows.groupby('doc_name',as_index = False)[mean_col].mean().sort_values(by=mean_col)
    if((wrong_correct=='wrong' and false_true=='false') or (wrong_correct=='correct' and false_true=='true')):
        statements_rows=statements_rows.tail(n_stat)['doc_name'].values
    else:
        statements_rows=statements_rows.head(n_stat)['doc_name'].values

    rows=data_rows.loc[data_rows['doc_name'].isin(statements_rows)]
    pathlib.Path(f"../Dati_1/rows").mkdir(parents=True, exist_ok=True) 
    rows.to_csv(f"../Dati_1/rows/{wrong_correct}_{false_true}_{n_stat}.csv", index=False)

# %%
create_rows_file(data,'wrong','false',['pants-on-fire'],'doc_truthfulness_value',n_stat, columns+['query_amount','response_position','selected_amount'])

# %%
create_rows_file(data,'wrong','true',['TRUE'],'doc_truthfulness_value',n_stat, columns+['query_amount','response_position','selected_amount'])

# %%
create_rows_file(data,'correct','false',['pants-on-fire'],'doc_truthfulness_value',n_stat, columns+['query_amount','response_position','selected_amount'])

# %%
create_rows_file(data,'correct','true',['TRUE'],'doc_truthfulness_value',n_stat, columns+['query_amount','response_position','selected_amount'])

# %% [markdown]
# ## File unici

# %%
filenames_rows = next(os.walk("../Dati_1/rows"), (None, None, []))[2]
df=pd.DataFrame()
for f in filenames_rows:
    r=pd.read_csv(f"../Dati_1/rows/{f}")
    r.insert(0, 'type', f.split(".")[0])
    df=pd.concat([df,r])
    df.to_csv(f"../Dati_1/all_rows_medical_{index}.csv",index=False)
    os.remove(f"../Dati_1/rows/{f}")
os.rmdir(f"../Dati_1/rows")

# %% [markdown]
# ## Statement groupby

# %%
transf_cols={
    'q_0_age_answer':['19-25', '26-35', '36-50', '50-80'],
    'q_0_school_answer': ['High school graduate or GED (etc.)', 'Some college (etc.)', '4 year college/bachelor degree', 'Postgrad. or professional schooling, no degree', 'Postgrad. or professional degree (etc.)'],
    'q_0_taxes_answer': ['Less than 10,000','10,000 to less than 20,000','20,000 to less than 30,000','30,000 to less than 40,000','40,000 to less than 50,000','50,000 to less than 75,000','75,000 to less than 100,000','100,000 to less than 150,000','150,000 or more'],
    'q_0_political_views_answer':['Very conservative', 'Conservative', 'Moderate', 'Liberal', 'Very liberal'],
    'q_0_consideration_answer':['Republican','Democrat','Independent','Something else'],
    'q_0_southern_border_answer':['Disagree','No opinion either way','Agree'],
    'q_0_environment_answer':['Disagree','No opinion either way','Agree'],
    'q_1_farmers_value':['wrong value','correct value'],
    'q_2_marks_value':['wrong value','correct value'],
    'q_3_athletics_value':['wrong value','correct value']
}

def transf_data(rows, tr_dict):
    rows['fre']=rows['doc_statement'].apply(lambda x : flesch_reading_ease(x))
    for name in rows.doc_name.unique():
        rows.loc[rows.doc_name==name, 'doc_statement']=rows.loc[rows.doc_name==name, 'doc_statement'].values[0]
    for k,v in tr_dict.items():
        rows[k]=pd.Categorical(rows[k], categories = v, ordered = True).codes

# %%
r= pd.read_csv(f"../Dati_1/all_rows_medical_{index}.csv")

d=r.copy()
transf_data(d, transf_cols)
df=d[columns+['doc_statement','type','fre']+columns_other].drop(['doc_claimant', 'doc_truthfulness_url','doc_name'], axis=1)

df_stat=df.groupby(['type', 'doc_statement'], as_index = False).mean().sort_values(by=['type','doc_truthfulness_value'])

def transf_back(x):
    for k,v in transf_cols.items():
        x[k]=f"{v[round(float(x[k]))]} ({float(x[k]):.2f})"
    return x

df_stat=df_stat.apply(transf_back, axis=1)

df_stat.to_csv(f'../Dati_1/groupby_statement_medical_{index}.csv', index=False)
